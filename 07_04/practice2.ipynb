# %%
class Car:
    def exclaim(self):
        print("我是一輛車")

# %%
my_car = Car()
my_car.exclaim()
# Out:
# 我是一輛車

# %%
# Yugo繼承Car的工具
class Yugo(Car):
    pass

# %%
my_yugo = Yugo()
my_yugo.exclaim()
# Out:
# 我是一輛車
