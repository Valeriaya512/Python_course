# %%
import csv

with open("考試分數_3年6班.csv","r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    #print(reader)
    for row in reader:
        print(row['學生姓名'])
# Out:
# 王小明
# 李美芳
# 張家豪
# 陳建宏
# 林志強
# 黃淑惠
# 吳明憲
# 蔡佩珊
# 郭政達
# 楊佳琪
# 趙冠宇
# 許家榮
# 鄭雅文
# 謝承翰
# 洪婉婷
# 曾志翔
# 劉美玲
# 蘇俊宏
# 葉雅婷
# 莊凱翔
# 呂佩穎
# 何志龍
# 羅佳穎
# 高家豪
# 蕭淑芬
# 潘冠宏
# 田雅琪
# 馮志強
# 蔣美惠
# 曹家榮
# 魏佩珊
# 彭承翰
# 袁佳琪
# 盧志宏
# 鄧婉婷
# 范家豪
# 汪美玲
# 賈俊宏
# 陸雅婷
# 韓凱翔
# 尤佩穎
# 柏志龍
# 焦佳穎
# 舒家豪
# 屈淑芬
# 項冠宏
# 祝雅琪
# 董志強
# 梁美惠
# 范家榮

# %%
import csv

with open("考試分數_3年6班.csv","r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    for row in reader:
        if int(row['數學']) > 90:
            print(row['學生姓名'])
# Out:
# 王小明
# 黃淑惠
# 楊佳琪
# 鄭雅文
# 劉美玲
# 葉雅婷
# 蔣美惠
# 魏佩珊
# 袁佳琪
# 汪美玲
# 陸雅婷
# 梁美惠
