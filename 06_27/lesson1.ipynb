# %% [markdown]
# ## numpy

# %%
# list

a = [1, 2, 3]
print(a + [4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# numpy

import numpy as np

b = np.array([1, 2, 3])
print(b + np.array([4, 5, 6]))
# Out:
# [5 7 9]

# %%
import numpy as np

arr1 = np.array([6, 7.5, 9.2, 0, 1])
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
arr2 = arr1 * 5
print(arr2)
# Out:
# [30.  37.5 46.   0.   5. ]

# %%
arr3 = arr1 / 10
print(arr3)
# Out:
# [0.6  0.75 0.92 0.   0.1 ]
