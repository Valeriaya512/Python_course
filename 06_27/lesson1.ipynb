# %% [markdown]
# numpy

# %%
# list

a = [1, 2, 3]
print(a + [4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# numpy

import numpy as np

b = np.array([1, 2, 3])
print(b + np.array([4, 5, 6]))
# Out:
# [5 7 9]
