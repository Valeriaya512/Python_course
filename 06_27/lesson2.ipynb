# %% [markdown]
# ## 資料清理

# %%
import pandas as pd

dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame.dtypes  # 在Pandas裡，字串欄位通常會顯示成object，不是str
len(dataFrame)
dataFrame.info()  # 看所有欄位有幾個非na
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   statistic_yyy       371 non-null    object
#  1   site_id             375 non-null    object
#  2   people_total        371 non-null    object
#  3   area                371 non-null    object
#  4   population_density  371 non-null    object
# dtypes: object(5)
# memory usage: 14.8+ KB

# %%
dataFrame.columns = ["統計年", "區域別", "年底人口數", "土地面積", "人口密度"] #改變欄位名稱
df = dataFrame.drop(index=0)
# 1. 移除統計年
df2 = df.drop('統計年', axis=1)
df2
# 2. 將「年底人口數」強制轉為數字，像 '…' 這樣的文字會被強制變成 NaN
df2["年底人口數"] = pd.to_numeric(df2["年底人口數"], errors="coerce")
df2
# 3. 這時候再用 dropna()，就能把原本是 '…' 的東沙、南沙群島（以及其他原本就是 NaN 的列）一次清乾淨！
df2 = df2.dropna(subset=["年底人口數"])
df2.info()
# # 4. 最後順利轉換為整數
df2["年底人口數"] = df2["年底人口數"].astype("int64")
df2["土地面積"] = df2["土地面積"].astype("float")
df2["人口密度"] = df2["人口密度"].astype("int64")
df2.info()
df2

# cmd+/，全部註解
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 368 entries, 1 to 368
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   區域別     368 non-null    object
#  1   年底人口數   368 non-null    float64
#  2   土地面積    368 non-null    object
#  3   人口密度    368 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 14.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 368 entries, 1 to 368
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   區域別     368 non-null    object
#  1   年底人口數   368 non-null    int64
#  2   土地面積    368 non-null    float64
#  3   人口密度    368 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 14.4+ KB
#         區域別   年底人口數     土地面積   人口密度
# 1    新北市板橋區  551480  23.1373  23835
# 2    新北市三重區  387484  16.3170  23747
# 3    新北市中和區  413590  20.1440  20532
# 4    新北市永和區  222585   5.7138  38956
# 5    新北市新莊區  416524  19.7383  21102
# ..      ...     ...      ...    ...
# 364  金門縣烏坵鄉     685   1.2000    571
# 365  連江縣南竿鄉    7544  10.4000    725
# 366  連江縣北竿鄉    2360   9.9000    238
# 367  連江縣莒光鄉    1624   4.7000    346
# 368  連江縣東引鄉    1352   3.8000    356
#
# [368 rows x 4 columns]

# %%
# 作業1 lesson2.md
import pandas as pd
import numpy as np

dataFrame = pd.read_csv('各班圖書借閱統計.csv')
dataFrame.columns = dataFrame.iloc[0]
dataFrame = dataFrame.iloc[1:].reset_index(drop=True)

dataFrame
# Out:
# 0           統計年    班級 學生人數  借閱冊數 平均每人借閱
# 0           112  一年甲班   35   420     12
# 1           112  一年乙班   33   264      8
# 2           112  一年丙班   34   510     15
# 3           112  二年甲班   36   288      8
# 4           112  二年乙班   32   480     15
# 5           112  二年丙班   35   245      7
# 6           112  三年甲班   30   600     20
# 7           112  三年乙班   31   372     12
# 8           112  三年丙班   33   198      6
# 9            合計    合計  299  3377   11.3
# 10   資料來源:學校圖書館   NaN  NaN   NaN    NaN
# 11  製表日期:112年6月   NaN  NaN   NaN    NaN
# 12    備註:含寒暑假借閱   NaN  NaN   NaN    NaN
# 13     本表僅供教學使用   NaN  NaN   NaN    NaN
